# %% [markdown]
# <a href="https://colab.research.google.com/github/Joezxc/BSU-Joe/blob/main/Chapter_6_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercise 1: Pizza Toppings 

topping_name='\nPlease enter the name of the topping you would like to add:'
topping_name+='\nEnter quit when you are finished'
while True:
  pizza=input(topping_name)

  if pizza=='quit':
     break
  else:
    print('I would love to add', pizza.title(),'!')

# %%
#Exercise 2: Movie Tickets:

print("Please enter the age to know the cost of your movie ticket.")
age = int(input())

if age < 3:
  print('the ticket is free.' )
elif age == 3:
   print('the ticket is $10.' )
elif age > 12:
   print('the ticket is $10.' )
elif age > 12:
  print('the ticket is $15.' )

# %%
#Exercise 3: Infinity 

i = 1
while i == 1:
  print('Good evening')
# Out:
# Streaming output truncated to the last 5000 lines.
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# Good evening
# ...

# %%
#Exercise 4: Deli 
sandwich_orders = ['Chicken', 'Tuna', 'Egg', 'Ham']
finished_sandwiches = []

while sandwich_orders:
  current_sandwich = sandwich_orders.pop()
  print("I made your " + current_sandwich + " sandwich.")
  finished_sandwiches.append(current_sandwich)

print("\n")
print('Sandwich Orders:')
for sandwich in finished_sandwiches:
  print(sandwich,'Sandwich')
# Out:
# I made your Ham sandwich.
# I made your Egg sandwich.
# I made your Tuna sandwich.
# I made your Chicken sandwich.
#
#
# Sandwich Orders:
# Ham Sandwich
# Egg Sandwich
# Tuna Sandwich
# Chicken Sandwich

# %%
#Exercise 5: No Pastrami
print('The deli has run out of Pastrami.')
print('\n')
sandwich_orders = ['Chicken', 'Tuna', 'Egg', 'Ham']
finished_sandwiches = []

for sandwich in sandwich_orders:
  if sandwich == 'Pastrami':
    sandwich_orders.remove(sandwich)

while sandwich_orders:
  current_sandwich = sandwich_orders.pop()
  print("I made your " + current_sandwich + " sandwich.")
  finished_sandwiches.append(current_sandwich)

print("\n")
print('Sandwich Orders:')
for sandwich in finished_sandwiches:
  print(sandwich,'Sandwich')

for sandwich in finished_sandwiches:
  print(sandwich,'Pastrami')
# Out:
# The deli has run out of Pastrami.
#
#
# I made your Ham sandwich.
# I made your Egg sandwich.
# I made your Tuna sandwich.
# I made your Chicken sandwich.
#
#
# Sandwich Orders:
# Ham Sandwich
# Egg Sandwich
# Tuna Sandwich
# Chicken Sandwich
# Ham Pastrami
# Egg Pastrami
# Tuna Pastrami
# Chicken Pastrami
